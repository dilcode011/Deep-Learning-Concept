# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
# 1. Load a pretrained YOLO model (v8 nano version - fastest)
model = YOLO('yolov8n.pt')

# %%
# 2. Run inference on an image
# (Ensure you have an image named 'test_image.jpg')
results = model('test_image.jpg')

# %%
# 3. Show Results
# YOLOv8 returns a list of results (one for each image)
for result in results:
    # Plot the result (draws boxes on the image)
    im_array = result.plot() 
    
    # Display using Matplotlib
    plt.figure(figsize=(10, 10))
    plt.imshow(cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

# %%
# Run this to open your webcam and detect objects live!
model = YOLO('yolov8n.pt')
results = model(source=0, show=True, conf=0.5)
