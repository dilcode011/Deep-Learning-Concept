# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image

# %%
def run_inception(img_path):
    # 1. Load InceptionV3
    # Inception expects images of size 299x299
    model = InceptionV3(weights='imagenet')
    
    # 2. Preprocess
    img = image.load_img(img_path, target_size=(299, 299))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = inception_preprocess(x) # Specific preprocessing for Inception
    
    # 3. Predict
    preds = model.predict(x)
    results = inception_decode(preds, top=3)[0]
    
    # 4. Show results
    show_image(img_path, title=f"Inception Prediction: {results[0][1]}")
    for i, (id, label, prob) in enumerate(results):
        print(f"{i+1}. {label}: {prob:.4f}")

# --- USAGE ---
# Upload an image named 'test.jpg' to your folder before running this!
# run_inception('test.jpg')
